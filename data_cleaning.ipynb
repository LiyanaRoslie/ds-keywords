# %% [markdown]
# ## Import necessary libraries

# %%
import pandas as pd
import numpy as np
import string
import re
import emoji

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Read files

# %%
articles_df = pd.read_csv("tds.csv", index_col=0)

# %%
articles_df.head()
# Out:
#   publish_date                                              title  \
# 0   2021-04-30  Better Software Writing Skills in Data Science...
# 1   2021-04-30  Forecasting at scale with Facebook Prophet — a...
# 2   2021-04-30  Five Subtle Pitfalls 99% Of Junior Python Deve...
# 3   2021-04-30      Four Deep Learning Papers to Read in May 2021
# 4   2021-04-30  Lessons from the First Two Data Scientists at ...
#
#           author                                                url  claps  \
# 0  Pascal Potvin  https://towardsdatascience.com/better-software...      1
# 1   Konrad Hoppe  https://towardsdatascience.com/forecasting-at-...     12
# 2  Mohammed Ayar  https://towardsdatascience.com/five-subtle-pit...    366
# 3   Robert Lange  https://towardsdatascience.com/four-deep-learn...    371
# 4     Matt Sosna  https://towardsdatascience.com/lessons-from-th...    140
#
#    responses  reading_time  paid  \
# 0          0             5     0
# 1          0             5     0
# 2          5             6     1
# 3          2             6     1
# 4          0            10     1
#
#                                              content
# 0  Pascal Potvin Apr 30·5 min read This week’s me...
# 1  Konrad Hoppe Apr 30·5 min read Time series for...
# 2  Mohammed Ayar Apr 30·6 min read If data scienc...
# 3  Robert Lange Apr 30·6 min read Welcome to the ...
# 4  Matt Sosna Apr 30·10 min read Data science in ...

# %%
articles_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42660 entries, 0 to 42659
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   publish_date  42660 non-null  object
#  1   title         42660 non-null  object
#  2   author        42660 non-null  object
#  3   url           42660 non-null  object
#  4   claps         42660 non-null  int64
#  5   responses     42660 non-null  int64
#  6   reading_time  42660 non-null  int64
#  7   paid          42660 non-null  int64
#  8   content       42322 non-null  object
# dtypes: int64(4), object(5)
# memory usage: 3.3+ MB

# %%
jobs_listing_df = pd.read_csv("DataScientist.csv", index_col=0)

# %%
jobs_listing_df.head()
# Out:
#    index                          Job Title               Salary Estimate  \
# 0      0              Senior Data Scientist  $111K-$181K (Glassdoor est.)
# 1      1  Data Scientist, Product Analytics  $111K-$181K (Glassdoor est.)
# 2      2               Data Science Manager  $111K-$181K (Glassdoor est.)
# 3      3                       Data Analyst  $111K-$181K (Glassdoor est.)
# 4      4             Director, Data Science  $111K-$181K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  ABOUT HOPPER\n\nAt Hopper, we’re on a mission ...     3.5
# 1  At Noom, we use scientifically proven methods ...     4.5
# 2  Decode_M\n\nhttps://www.decode-m.com/\n\nData ...    -1.0
# 3  Sapphire Digital seeks a dynamic and driven mi...     3.4
# 4  Director, Data Science - (200537)\nDescription...     3.4
#
#                       Company Name       Location      Headquarters  \
# 0                      Hopper\n3.5   New York, NY  Montreal, Canada
# 1                     Noom US\n4.5   New York, NY      New York, NY
# 2                         Decode_M   New York, NY      New York, NY
# 3            Sapphire Digital\n3.4  Lyndhurst, NJ     Lyndhurst, NJ
# 4  United Entertainment Group\n3.4   New York, NY      New York, NY
#
#                      Size  Founded  Type of ownership  \
# 0   501 to 1000 employees     2007  Company - Private
# 1  1001 to 5000 employees     2008  Company - Private
# 2       1 to 50 employees       -1            Unknown
# 3    201 to 500 employees     2019  Company - Private
# 4     51 to 200 employees     2007  Company - Private
#
#                     Industry                  Sector  \
# 0            Travel Agencies        Travel & Tourism
# 1  Health, Beauty, & Fitness       Consumer Services
# 2                         -1                      -1
# 3                   Internet  Information Technology
# 4    Advertising & Marketing       Business Services
#
#                     Revenue               Competitors Easy Apply
# 0  Unknown / Non-Applicable                        -1         -1
# 1  Unknown / Non-Applicable                        -1         -1
# 2  Unknown / Non-Applicable                        -1       True
# 3  Unknown / Non-Applicable      Zocdoc, Healthgrades         -1
# 4  Unknown / Non-Applicable  BBDO, Grey Group, Droga5         -1

# %%
jobs_listing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3909 entries, 0 to 3908
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   index              3909 non-null   int64
#  1   Job Title          3909 non-null   object
#  2   Salary Estimate    3909 non-null   object
#  3   Job Description    3909 non-null   object
#  4   Rating             3909 non-null   float64
#  5   Company Name       3909 non-null   object
#  6   Location           3909 non-null   object
#  7   Headquarters       3909 non-null   object
#  8   Size               3909 non-null   object
#  9   Founded            3909 non-null   int64
#  10  Type of ownership  3909 non-null   object
#  11  Industry           3909 non-null   object
#  12  Sector             3909 non-null   object
#  13  Revenue            3909 non-null   object
#  14  Competitors        3909 non-null   object
#  15  Easy Apply         3909 non-null   object
# dtypes: float64(1), int64(2), object(13)
# memory usage: 519.2+ KB

# %% [markdown]
# ## Common methods to clean data

# %%
def remove_punctuations(text):
    for punctuation in string.punctuation:
        text = text.replace(punctuation, '')
    return text

# %%
def remove_escape_special_chars(text):
    for ch in ['\'','\"','\\','\n','\r', '\t','\b','\f','\ooo', '·', '•']:
        if ch in text:
            text = text.replace(ch, "")
    return text

# %%
def remove_emojis(df_col):
    df_col = df_col.str.replace('[^\w\s#@/:%.,_-]', '', flags=re.UNICODE)
    return df_col

# %%
def remove_col_content(df, col_to_remove, ref_col):
    return df.apply(lambda row : row[col_to_remove].replace(str(row[ref_col]), ''), axis=1)

# %% [markdown]
# ## Clean data for articles dataframe

# %%
# remove rows that contain missing content data
articles_df = articles_df[articles_df['content'].notna()]

# %%
# make all words in content to be lowercase
articles_df['cleaned_content'] = articles_df['content'].str.lower()

# %%
# make all words in author to be lowercase
articles_df['cleaned_author'] = articles_df['author'].str.lower()

# %%
# remove punctuations in content
articles_df["cleaned_content"] = articles_df["cleaned_content"].apply(remove_punctuations)

# %%
# remove escape and special characters in content
articles_df["cleaned_content"] = articles_df["cleaned_content"].apply(remove_escape_special_chars)

# %%
# remove emojis in content
articles_df['cleaned_content'] = remove_emojis(articles_df['cleaned_content'])

# %%
# remove author names inside articles content
articles_df['cleaned_content'] = remove_col_content(articles_df, 'cleaned_content', 'cleaned_author')

# %%
# remove the first few words until the word read
# this phrase only states how long a person will take to read the article
# therefore this phrase is irrelevant to the keyword

articles_df['cleaned_content'] = articles_df['cleaned_content'].str.split(r'read').str[1:].str.join(" ")

# %%
# remove duplicated articles content
duplicated_articles = articles_df[articles_df.duplicated(['cleaned_content'])]
articles_df.drop(duplicated_articles.index, inplace=True)
articles_df
# Out:
#       publish_date                                              title  \
# 0       2021-04-30  Better Software Writing Skills in Data Science...
# 1       2021-04-30  Forecasting at scale with Facebook Prophet — a...
# 2       2021-04-30  Five Subtle Pitfalls 99% Of Junior Python Deve...
# 3       2021-04-30      Four Deep Learning Papers to Read in May 2021
# 4       2021-04-30  Lessons from the First Two Data Scientists at ...
# ...            ...                                                ...
# 42655   2014-11-25  Lessons Learned From The Higgs Boson Kaggle Ch...
# 42656   2014-11-11         What makes a good data scientist-engineer?
# 42657   2013-10-10           Avoiding an Epic Data Visualization Fail
# 42658   2011-01-16                                   Ockham’s Spatula
# 42659   2010-11-21                        Fifty Ways to Fix your Data
#
#                 author                                                url  \
# 0        Pascal Potvin  https://towardsdatascience.com/better-software...
# 1         Konrad Hoppe  https://towardsdatascience.com/forecasting-at-...
# 2        Mohammed Ayar  https://towardsdatascience.com/five-subtle-pit...
# 3         Robert Lange  https://towardsdatascience.com/four-deep-learn...
# 4           Matt Sosna  https://towardsdatascience.com/lessons-from-th...
# ...                ...                                                ...
# 42655  John Wittenauer  https://towardsdatascience.com/lessons-learned...
# 42656  Nikhil Dandekar  https://towardsdatascience.com/what-makes-a-go...
# 42657  Tricia Aanderud  https://towardsdatascience.com/avoiding-an-epi...
# 42658     Charlie Kufs  https://towardsdatascience.com/ockhams-spatula...
# 42659     Charlie Kufs  https://towardsdatascience.com/fifty-ways-to-f...
#
#        claps  responses  reading_time  paid  \
# 0          1          0             5     0
# 1         12          0             5     0
# 2        366          5             6     1
# 3        371          2             6     1
# 4        140          0            10     1
# ...      ...        ...           ...   ...
# 42655      6          0             6     0
# 42656    166          0             3     0
# 42657    180          1             5     1
# 42658      5          0             7     1
# 42659     12          0             9     1
#
#                                                  content  \
# 0      Pascal Potvin Apr 30·5 min read This week’s me...
# 1      Konrad Hoppe Apr 30·5 min read Time series for...
# 2      Mohammed Ayar Apr 30·6 min read If data scienc...
# 3      Robert Lange Apr 30·6 min read Welcome to the ...
# 4      Matt Sosna Apr 30·10 min read Data science in ...
# ...                                                  ...
# 42655  John Wittenauer Nov 25, 2014·6 min read This c...
# 42656  Nikhil Dandekar Nov 11, 2014·3 min read The te...
# 42657  Tricia Aanderud Oct 10, 2013·5 min read Effect...
# 42658  Charlie Kufs Jan 16, 2011·7 min read Model bui...
# 42659  Charlie Kufs Nov 21, 2010·9 min read The probl...
#
#                                          cleaned_content   cleaned_author
# 0       this weeks mentoring and post is based on the...    pascal potvin
# 1       time series forecasting is usually a complex ...     konrad hoppe
# 2       if data science is the sexiest job of the 21s...    mohammed ayar
# 3       welcome to the end of april edition of the ma...     robert lange
# 4       data science in startups is notorious for bei...       matt sosna
# ...                                                  ...              ...
# 42655   this content originally appeared on curious i...  john wittenauer
# 42656   the term data scientist has been used lately ...  nikhil dandekar
# 42657   effective data visualizations have some commo...  tricia aanderud
# 42658   model building is like climbing a mountain it...     charlie kufs
# 42659   the problem is all about your scales she said...     charlie kufs
#
# [42220 rows x 11 columns]

# %% [markdown]
# ### check articles dataframe after cleaning

# %%
articles_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 42220 entries, 0 to 42659
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   publish_date     42220 non-null  object
#  1   title            42220 non-null  object
#  2   author           42220 non-null  object
#  3   url              42220 non-null  object
#  4   claps            42220 non-null  int64
#  5   responses        42220 non-null  int64
#  6   reading_time     42220 non-null  int64
#  7   paid             42220 non-null  int64
#  8   content          42220 non-null  object
#  9   cleaned_content  42220 non-null  object
#  10  cleaned_author   42220 non-null  object
# dtypes: int64(4), object(7)
# memory usage: 3.9+ MB

# %% [markdown]
# ## Clean data for Data Science jobs dataframe

# %%
# drop column index 0 that contains index
jobs_listing_df.drop(jobs_listing_df.columns[0], axis=1, inplace=True)

# %%
jobs_listing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3909 entries, 0 to 3908
# Data columns (total 15 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Job Title          3909 non-null   object
#  1   Salary Estimate    3909 non-null   object
#  2   Job Description    3909 non-null   object
#  3   Rating             3909 non-null   float64
#  4   Company Name       3909 non-null   object
#  5   Location           3909 non-null   object
#  6   Headquarters       3909 non-null   object
#  7   Size               3909 non-null   object
#  8   Founded            3909 non-null   int64
#  9   Type of ownership  3909 non-null   object
#  10  Industry           3909 non-null   object
#  11  Sector             3909 non-null   object
#  12  Revenue            3909 non-null   object
#  13  Competitors        3909 non-null   object
#  14  Easy Apply         3909 non-null   object
# dtypes: float64(1), int64(1), object(13)
# memory usage: 488.6+ KB

# %%
# rename columns
jobs_listing_df.columns = ['job_title', 'salary_estimate', 'job_description', 'rating', 'company_name', 
                           'location', 'headquarters', 'size', 'founded', 'type_of_ownership', 'industry', 'sector',
                           'revenue', 'competitors', 'easy_apply']

# %%
# make all words in job description to be lowercase
jobs_listing_df['cleaned_job_description'] = jobs_listing_df['job_description'].str.lower()

# %%
# make all words in company name to be lowercase
jobs_listing_df['cleaned_company_name'] = jobs_listing_df['company_name'].str.lower()

# %%
# remove punctuations in job description
jobs_listing_df["cleaned_job_description"] = jobs_listing_df["cleaned_job_description"].apply(remove_punctuations)

# %%
# remove escape and special characters in job description
jobs_listing_df["cleaned_job_description"] = jobs_listing_df["cleaned_job_description"].apply(remove_escape_special_chars)

# %%
# remove emojis in job description 
jobs_listing_df["cleaned_job_description"] = remove_emojis(jobs_listing_df["cleaned_job_description"])

# %%
# extract company name before \n appears
jobs_listing_df["cleaned_company_name"] = jobs_listing_df["cleaned_company_name"].str.split('\n').str[0]

# %%
# remove company names inside job description
jobs_listing_df["cleaned_job_description"] = remove_col_content(jobs_listing_df, 'cleaned_job_description', 'cleaned_company_name')

# %%
# remove duplicated job description
duplicated_job = jobs_listing_df[jobs_listing_df.duplicated(["cleaned_job_description"])]
jobs_listing_df.drop(duplicated_job.index, inplace=True)
jobs_listing_df
# Out:
#                                               job_title  \
# 0                                 Senior Data Scientist
# 1                     Data Scientist, Product Analytics
# 2                                  Data Science Manager
# 3                                          Data Analyst
# 4                                Director, Data Science
# ...                                                 ...
# 3903                       Cyber Security Data Engineer
# 3904                                  AWS Data Engineer
# 3906                   Security Analytics Data Engineer
# 3907                   Security Analytics Data Engineer
# 3908  Patient Safety Physician or Safety Scientist -...
#
#                    salary_estimate  \
# 0     $111K-$181K (Glassdoor est.)
# 1     $111K-$181K (Glassdoor est.)
# 2     $111K-$181K (Glassdoor est.)
# 3     $111K-$181K (Glassdoor est.)
# 4     $111K-$181K (Glassdoor est.)
# ...                            ...
# 3903   $55K-$112K (Glassdoor est.)
# 3904   $55K-$112K (Glassdoor est.)
# 3906   $55K-$112K (Glassdoor est.)
# 3907   $55K-$112K (Glassdoor est.)
# 3908   $55K-$112K (Glassdoor est.)
#
#                                         job_description  rating  \
# 0     ABOUT HOPPER\n\nAt Hopper, we’re on a mission ...     3.5
# 1     At Noom, we use scientifically proven methods ...     4.5
# 2     Decode_M\n\nhttps://www.decode-m.com/\n\nData ...    -1.0
# 3     Sapphire Digital seeks a dynamic and driven mi...     3.4
# 4     Director, Data Science - (200537)\nDescription...     3.4
# ...                                                 ...     ...
# 3903  ApTask is a leading staffing and recruitment c...     3.9
# 3904  About Us\n\nTachyon Technologies is a Digital ...     4.4
# 3906  Job DescriptionThe Security Analytics Data Eng...     3.8
# 3907  The Security Analytics Data Engineer will inte...     4.0
# 3908  Help us transform patients' lives.\nAt UCB, we...     3.7
#
#                          company_name       location      headquarters  \
# 0                         Hopper\n3.5   New York, NY  Montreal, Canada
# 1                        Noom US\n4.5   New York, NY      New York, NY
# 2                            Decode_M   New York, NY      New York, NY
# 3               Sapphire Digital\n3.4  Lyndhurst, NJ     Lyndhurst, NJ
# 4     United Entertainment Group\n3.4   New York, NY      New York, NY
# ...                               ...            ...               ...
# 3903                      ApTask\n3.9     Dublin, OH        Iselin, NJ
# 3904        Tachyon Technologies\n4.4     Dublin, OH        Irving, TX
# 3906              PDS Tech, Inc.\n3.8     Dublin, OH        Irving, TX
# 3907  Data Resource Technologies\n4.0     Dublin, OH         Omaha, NE
# 3908                         UCB\n3.7     Slough, OH  Brussel, Belgium
#
#                          size  founded  type_of_ownership  \
# 0       501 to 1000 employees     2007  Company - Private
# 1      1001 to 5000 employees     2008  Company - Private
# 2           1 to 50 employees       -1            Unknown
# 3        201 to 500 employees     2019  Company - Private
# 4         51 to 200 employees     2007  Company - Private
# ...                       ...      ...                ...
# 3903     201 to 500 employees     2010  Company - Private
# 3904     201 to 500 employees     2011  Company - Private
# 3906  5001 to 10000 employees     1977  Company - Private
# 3907        1 to 50 employees       -1  Company - Private
# 3908  5001 to 10000 employees       -1   Company - Public
#
#                        industry                     sector  \
# 0               Travel Agencies           Travel & Tourism
# 1     Health, Beauty, & Fitness          Consumer Services
# 2                            -1                         -1
# 3                      Internet     Information Technology
# 4       Advertising & Marketing          Business Services
# ...                         ...                        ...
# 3903                IT Services     Information Technology
# 3904                IT Services     Information Technology
# 3906     Staffing & Outsourcing          Business Services
# 3907                 Accounting         Accounting & Legal
# 3908  Biotech & Pharmaceuticals  Biotech & Pharmaceuticals
#
#                          revenue                                  competitors  \
# 0       Unknown / Non-Applicable                                           -1
# 1       Unknown / Non-Applicable                                           -1
# 2       Unknown / Non-Applicable                                           -1
# 3       Unknown / Non-Applicable                         Zocdoc, Healthgrades
# 4       Unknown / Non-Applicable                     BBDO, Grey Group, Droga5
# ...                          ...                                          ...
# 3903   $50 to $100 million (USD)  Collabera, Mitchell Martin, The Judge Group
# 3904    $10 to $25 million (USD)                                           -1
# 3906  $100 to $500 million (USD)                                           -1
# 3907  Less than $1 million (USD)                                           -1
# 3908      $2 to $5 billion (USD)                                       AbbVie
#
#      easy_apply                            cleaned_job_description  \
# 0            -1  about at  were on a mission to make booking tr...
# 1            -1  at noom we use scientifically proven methods t...
# 2          True  decodemhttpswwwdecodemcomdata science manager ...
# 3            -1   seeks a dynamic and driven midlevel data anal...
# 4            -1  director data science  200537descriptionedelma...
# ...         ...                                                ...
# 3903         -1   is a leading staffing and recruitment company...
# 3904         -1  about us is a digital transformation consultin...
# 3906         -1  job descriptionthe security analytics data eng...
# 3907         -1  the security analytics data engineer will inte...
# 3908         -1  help us transform patients livesat  we put our...
#
#             cleaned_company_name
# 0                         hopper
# 1                        noom us
# 2                       decode_m
# 3               sapphire digital
# 4     united entertainment group
# ...                          ...
# 3903                      aptask
# 3904        tachyon technologies
# 3906              pds tech, inc.
# 3907  data resource technologies
# 3908                         ucb
#
# [3690 rows x 17 columns]

# %% [markdown]
# ### check jobs listing dataframe after cleaning

# %%
jobs_listing_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3690 entries, 0 to 3908
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   job_title                3690 non-null   object
#  1   salary_estimate          3690 non-null   object
#  2   job_description          3690 non-null   object
#  3   rating                   3690 non-null   float64
#  4   company_name             3690 non-null   object
#  5   location                 3690 non-null   object
#  6   headquarters             3690 non-null   object
#  7   size                     3690 non-null   object
#  8   founded                  3690 non-null   int64
#  9   type_of_ownership        3690 non-null   object
#  10  industry                 3690 non-null   object
#  11  sector                   3690 non-null   object
#  12  revenue                  3690 non-null   object
#  13  competitors              3690 non-null   object
#  14  easy_apply               3690 non-null   object
#  15  cleaned_job_description  3690 non-null   object
#  16  cleaned_company_name     3690 non-null   object
# dtypes: float64(1), int64(1), object(15)
# memory usage: 518.9+ KB

# %% [markdown]
# ## Export both dataframes to csv file (without index column)

# %%
articles_df.to_csv('cleaned_articles.csv', index=False)

# %%
jobs_listing_df.to_csv('cleaned_jobs_listings.csv', index=False)
